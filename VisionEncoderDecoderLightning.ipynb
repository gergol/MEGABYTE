# %%
# %load_ext autoreload
# %autoreload 2

from MEGABYTE_pytorch.lightning_modules import VisionEncoderDecoderModel
from MEGABYTE_pytorch import MEGABYTE

import random
import tqdm
import gzip
import numpy as np
import torch
import torch.optim as optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
import lightning as L

# constants

NUM_BATCHES = int(1e5)
BATCH_SIZE = 3
GRADIENT_ACCUMULATE_EVERY = 4
LEARNING_RATE = 2e-4
VALIDATE_EVERY  = 100
GENERATE_EVERY  = 500
PRIME_LEN = 100
SEQ_LEN = 128

# %%
import torch
from transformers import PreTrainedTokenizer

from typing import Dict, List

class MegabyteTokenizer():
    def __init__(self, eos_token_id=256, pad_token_id=257, max_len=128):

        
        self._token_ids = {chr(i): i for i in range(256)}
        self._token_ids["<eos>"] =  eos_token_id
        self._token_ids["<pad>"] = pad_token_id
        
        self._id_tokens: Dict[int, str] = {value: key for key, value in self._token_ids.items()}

        
        #super().__init__(max_len=max_len)
        
        
        self.eos_token_id = eos_token_id
        self.pad_token_id = pad_token_id
        self.bos_token_id = eos_token_id
        
        self.max_len = max_len
        
    def tokenize(self, text, return_tensors="pt"):
        
        #tokens = torch.frombuffer(bytearray(text.encode("utf-8")), dtype=torch.uint8).to(torch.int64)
        #
        #tokens = torch.cat((tokens, torch.full((1, ), self.eos_token_id)), dim=-1)
        #tokens = tokens.reshape(1, tokens.numel())
        
        tokens = torch.frombuffer(bytearray(text.encode("utf-8")), dtype=torch.uint8).to(torch.int64)
        tokens = torch.cat((tokens, torch.full((1, ), self.eos_token_id)), dim=-1)
        #tokens += [self.eos_token_id]
        return  tokens
    
    def decode(self, token_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True):
        if len(token_ids.shape) == 1:
            token_ids = token_ids.unsqueeze(0)
        texts = []
        for id_list in token_ids:
            line_ids = filter(lambda x: 0<=x and x<256, id_list.cpu().tolist())
            text = bytearray(list(line_ids)).decode("utf-8")
            texts.append(text)

        return texts
    
    def pad(self, toks):
        assert isinstance(toks, torch.Tensor) or isinstance(toks, list)
        
        if len(toks) == 0:
            return None
        batch_size = None
        if isinstance(toks, torch.Tensor):
            assert len(toks.shape) == 2
            batch_size = toks.shape[0]
        elif isinstance(toks, list):
            assert isinstance(toks[0], torch.Tensor)
            batch_size = len(toks)
            
        ret = torch.full((batch_size, self.max_len), self.pad_token_id, dtype=torch.int64)
        for i, row in enumerate(toks):
            sz = min(len(row), self.max_len)
            ret[i, :sz] = row[:sz]
        return ret
    
    def __call__(self, inputs, **kwargs):
        if isinstance(inputs, list):
            toks = [self.tokenize(i) for i in inputs]
            return self.pad(toks)
        else:
            return self.pad(self.tokenize(inputs))
    
    def _convert_token_to_id(self, token: str) -> int:
        return self._token_ids[token] if token in self._token_ids else self.unk_token_id

    def _convert_id_to_token(self, index: int) -> str:
        return self._id_tokens[index] if index in self._id_tokens else self.unk_token

    def get_vocab(self) -> Dict[str, int]:
        return self._token_ids.copy()


tokenizer = MegabyteTokenizer(max_len = SEQ_LEN)

tokenizer.decode(tokenizer(["\0blah hal mal \x0182 ", "123"]))
# Out:
# ['\x00blah hal mal \x0182 ', '123']

# %%
tokenizer(["\0blah hal mal \x0182 ", "123"]).dtype
# Out:
# torch.int64

# %%
from transformers import ViTImageProcessor, ViTModel
image_processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')
# Out:
# 2024-09-04 15:43:00.904506: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 15:43:01.468599: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from datasets import load_dataset


ds = load_dataset("jbarat/plant_species")

class_names = ds['train'].features['label'].names

verbs = ['shows', 'displays', 'contains', 'images']
import random

def add_text(sample):
    txt = f"This picture {random.choice(verbs)} a {class_names[sample['label']]} plant"
    return {
        'pixel_values': image_processor(sample['image'], return_tensors='pt')['pixel_values'].squeeze(), 
        'input_ids': tokenizer([txt], return_tensors='pt').squeeze()
    }

dataset = ds.map(add_text)
dataset.set_format("pt")

# %%
decoder = MEGABYTE(
    vocab_size=len(tokenizer.get_vocab()), 
    hidden_sizes=(768, 256), 
    num_hidden_layers=(6, 4), 
    max_sequence_lengths=(16, 8), flash_attn=True, add_cross_attention=True).cuda()
# Out:
# Non-A100 GPU detected, using math or mem efficient attention if input tensor is on cuda

# %%
class TestDataModule(L.LightningDataModule):
    
    def __init__(self, dataset, tokenizer, image_processor, batch_size: int = 32, num_workers=4, text_only=False):
        super().__init__()
        self.batch_size = batch_size
        self.tokenizer = tokenizer
        self.image_processor = image_processor
        self.dataset = dataset
        self.num_workers = num_workers
        self.text_only = text_only

    def setup(self, stage=None):
        from datasets import load_dataset

        if self.text_only:
            self.dataset = self.dataset.select_columns(['input_ids'])
        else:
            self.dataset = self.dataset.select_columns(['pixel_values', 'input_ids'])
        self.dataset.set_format("pt")
        
    def train_dataloader(self):
        return torch.utils.data.DataLoader(self.dataset['train'], batch_size=self.batch_size, shuffle=True, num_workers=self.num_workers)

    def val_dataloader(self):
        return torch.utils.data.DataLoader(self.dataset['train'], batch_size=self.batch_size, num_workers=self.num_workers)



datamodule = TestDataModule(
    dataset=dataset, 
    tokenizer=tokenizer, 
    image_processor=image_processor, 
    batch_size=32, text_only=False)

datamodule.setup()

# %%
encoder = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')

# %%
model = VisionEncoderDecoderModel(encoder=encoder, decoder=decoder)

# %%
trainer = L.Trainer(gradient_clip_algorithm='norm', gradient_clip_val=1.0)
model.cuda()
trainer.fit(model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/gerald/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/loops/utilities.py:72: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/gerald/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/core/optimizer.py:377: Found unsupported keys in the optimizer configuration: {'metric'}
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | ViTModel | 86.4 M | eval
# 1 | decoder | MEGABYTE | 54.8 M | train
# ---------------------------------------------
# 141 M     Trainable params
# 0         Non-trainable params
# 141 M     Total params
# 564.673   Total estimated model params size (MB)
# 222       Modules in train mode
# 227       Modules in eval mode
# Sanity Checking: |                                                                                            …
# /usr/lib/python3.10/contextlib.py:103: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# /home/gerald/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (25) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |                                                                                                   …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:574, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     568 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     569     self.state.fn,
#     570     ckpt_path,
#     571     model_provided=True,
#     572     model_connected=self.lightning_module is not None,
#     573 )
# --> 574 self._run(model, ckpt_path=ckpt_path)
#     576 assert self.state.stopped
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:981, in Trainer._run(self, model, ckpt_path)
#     978 # ----------------------------
#     979 # RUN THE TRAINER
#     980 # ----------------------------
# --> 981 results = self._run_stage()
#     983 # ----------------------------
#     984 # POST-Training CLEAN UP
#     985 # ----------------------------
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:1025, in Trainer._run_stage(self)
#    1024 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025     self.fit_loop.run()
#    1026 return None
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:206, in _FitLoop.run(self)
#     205 self.advance()
# --> 206 self.on_advance_end()
#     207 self._restarting = False
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:378, in _FitLoop.on_advance_end(self)
#     377 call._call_lightning_module_hook(trainer, "on_train_epoch_end")
# --> 378 call._call_callback_hooks(trainer, "on_train_epoch_end", monitoring_callbacks=True)
#     380 trainer._logger_connector.on_epoch_end()
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:218, in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     217         with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 218             fn(trainer, trainer.lightning_module, *args, **kwargs)
#     220 if pl_module:
#     221     # restore current_fx when nested context
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:325, in ModelCheckpoint.on_train_epoch_end(self, trainer, pl_module)
#     324 if self._every_n_epochs >= 1 and (trainer.current_epoch + 1) % self._every_n_epochs == 0:
# --> 325     self._save_topk_checkpoint(trainer, monitor_candidates)
#     326 self._save_last_checkpoint(trainer, monitor_candidates)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:387, in ModelCheckpoint._save_topk_checkpoint(self, trainer, monitor_candidates)
#     386 else:
# --> 387     self._save_none_monitor_checkpoint(trainer, monitor_candidates)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:715, in ModelCheckpoint._save_none_monitor_checkpoint(self, trainer, monitor_candidates)
#     714 previous, self.best_model_path = self.best_model_path, filepath
# --> 715 self._save_checkpoint(trainer, filepath)
#     717 if self.save_top_k == 1 and previous and self._should_remove_checkpoint(trainer, previous, filepath):
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:390, in ModelCheckpoint._save_checkpoint(self, trainer, filepath)
#     389 def _save_checkpoint(self, trainer: "pl.Trainer", filepath: str) -> None:
# --> 390     trainer.save_checkpoint(filepath, self.save_weights_only)
#     392     self._last_global_step_saved = trainer.global_step
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:1365, in Trainer.save_checkpoint(self, filepath, weights_only, storage_options)
#    1364 checkpoint = self._checkpoint_connector.dump_checkpoint(weights_only)
# -> 1365 self.strategy.save_checkpoint(checkpoint, filepath, storage_options=storage_options)
#    1366 self.strategy.barrier("Trainer.save_checkpoint")
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/strategies/strategy.py:490, in Strategy.save_checkpoint(self, checkpoint, filepath, storage_options)
#     489 if self.is_global_zero:
# --> 490     self.checkpoint_io.save_checkpoint(checkpoint, filepath, storage_options=storage_options)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/fabric/plugins/io/torch_io.py:58, in TorchCheckpointIO.save_checkpoint(self, checkpoint, path, storage_options)
#      57 fs.makedirs(os.path.dirname(path), exist_ok=True)
# ---> 58 _atomic_save(checkpoint, path)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/fabric/utilities/cloud_io.py:90, in _atomic_save(checkpoint, filepath)
#      89 with fs.transaction, fs.open(urlpath, "wb") as f:
# ---> 90     f.write(bytesbuffer.getvalue())
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/fsspec/implementations/local.py:369, in LocalFileOpener.write(self, *args, **kwargs)
#     368 def write(self, *args, **kwargs):
# --> 369     return self.f.write(*args, **kwargs)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 trainer = L.Trainer(gradient_clip_algorithm='norm', gradient_clip_val=1.0)
#       2 model.cuda()
# ----> 3 trainer.fit(model, datamodule=datamodule)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:538, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536 self.state.status = TrainerStatus.RUNNING
#     537 self.training = True
# --> 538 call._call_and_handle_interrupt(
#     539     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540 )
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
#torch.save(model.cpu().state_dict(), "vision_text_model.pt")

# %%
model = VisionEncoderDecoderModel(encoder=encoder, decoder=decoder, device='cuda')
state_dict = torch.load("vision_text_model.pt", weights_only=True)
model.load_state_dict(state_dict)
model = model.eval()

# %%
sample =  dataset['train'][730]
img = sample['image']
pixel_values = sample['pixel_values']
toks = sample['input_ids']
from torchvision.transforms import ToPILImage

to_pil = ToPILImage()
print(tokenizer.decode(toks))
to_pil(img.cpu().numpy())
# Out:
# ['This picture displays a allium_sativum plant']
# <PIL.Image.Image image mode=RGB size=375x500>

# %%
model.eval()

with torch.no_grad():
    model.encoder.cuda()
    image_embedding = model.encoder(pixel_values.cuda().unsqueeze(0)).last_hidden_state
    image_embedding

# %%
from MEGABYTE_pytorch.megabyte import reduce_mult, gumbel_sample, top_k, exists
from einops import rearrange

def generate(
    model, 
    prime = None, 
    filter_thres = 0.9, 
    temperature = 1., 
    default_batch_size = 1,
    encoder_hidden_states=None
):
    
    total_seq_len = reduce_mult(model.decoder.max_seq_len)
    device = next(model.decoder.parameters()).device
    print(device)

    if not exists(prime):
        prime = torch.empty((default_batch_size, 0), dtype = torch.long, device = device)
    prime = prime.to(device)

    seq = prime
    batch = seq.shape[0]

    for _ in range(total_seq_len - seq.shape[-1]):
        logits = model.forward(input_ids=seq, encoder_hidden_states=encoder_hidden_states)[:, -1]
        #logits = decoder.forward(seq)[:, -1]
        logits = top_k(logits, thres = filter_thres)
        sampled = gumbel_sample(logits, dim = -1, temperature = temperature)
        seq = torch.cat((seq, rearrange(sampled, 'b -> b 1')), dim = -1)

    return seq.reshape(batch, *decoder.max_seq_len).flatten(-1)

prompt = 'This pic'
seq = tokenizer([prompt])[:, :len(prompt)].cuda()

model.cuda()

Y = generate(model, seq, encoder_hidden_states=image_embedding)
#print(Y)
tokenizer.decode(Y.flatten())


#TODO HIER WEITER!!!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 38
#      34 seq = tokenizer([prompt])[:, :len(prompt)].cuda()
#      36 model.cuda()
# ---> 38 Y = generate(model, seq, encoder_hidden_states=image_embedding)
#      39 #print(Y)
#      40 tokenizer.decode(Y.flatten())
#
# Cell In[14], line 13, in generate(model, prime, filter_thres, temperature, default_batch_size, encoder_hidden_states)
#       4 def generate(
#       5     model,
#       6     prime = None,
#    (...)
#      10     encoder_hidden_states=None
#      11 ):
# ---> 13     total_seq_len = reduce_mult(model.decoder.max_seq_len)
#      14     device = next(model.decoder.parameters()).device
#      15     print(device)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'MEGABYTE' object has no attribute 'max_seq_len'

# %%
Y.flatten()
# Out:
# tensor([ 84, 104, 105, 115,  32, 112, 105,  99, 116, 117, 114, 101,  32, 115,
#         104, 111, 119, 115,  32,  97,  32,  97, 101,  99, 104, 109, 101,  97,
#          95, 102,  97, 115,  99, 105,  97, 116,  97,  32, 112, 108,  97, 110,
#         116, 256, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257])

# %%
# Out:
# ['This picture shows a aechmea_fasciata plant']

# %%
beams = torch.Tensor([[tokenizer.pad_token_id]] * num_beams).cuda().int()

# %%
num_beams = 3


beams = torch.Tensor([[tokenizer.pad_token_id]] * num_beams).cuda().int()
probs = torch.zeros((num_beams,)).float().cuda()


MAX_LEN = 24

print(beams.shape, probs)
model.eval()
with torch.no_grad():
    for n in range(MAX_LEN):
        #print(beams.shape)
        model.cuda()
        #result = model.decoder.model(seq, encoder_hidden_states=image_embedding)
        #print("input shape:", beams.shape)
        result = model(beams)
        #print("result.shape", result.shape)
        # (B, T, V)
        best_toks = torch.topk(result[:, -1, :], num_beams, dim=-1)
        if beams.shape[-1] == 1:
            #initial run
            beams = best_toks.indices[0].reshape((-1, 1))
            probs = best_toks.values[0]
            #print("Initial run: ", beams.tolist(), probs.tolist(), beams.shape)
            beams = torch.cat((beams, torch.Tensor([[tokenizer.pad_token_id]] * num_beams).cuda()), dim=-1).int()
            continue
                

        all_new_probs = (probs.repeat((num_beams, 1)).transpose(1, 0).reshape(1, -1) * n + best_toks.values.reshape(1,-1)) / (n+1)
        #print(all_new_probs)
        selected = torch.topk(all_new_probs, num_beams)
        selected_beam_indices = selected.indices.squeeze() // num_beams
        selected_new_toks = selected.indices.squeeze() - selected_beam_indices

        selected_beams = beams[selected_beam_indices]
        #selected_beams[-1] = selected_new_toks
        selected_tok_indices = selected_beam_indices * num_beams + selected_new_toks
        selected_toks = best_toks.indices.reshape(-1)[selected_tok_indices]
        selected_probs = all_new_probs.reshape(-1)[selected_tok_indices]
        selected_toks, selected_probs
        selected_beams[:, -1] = selected_toks.squeeze()
        print("txt: ", tokenizer.decode(selected_beams)) 
        beams = torch.cat((selected_beams, torch.Tensor([[tokenizer.pad_token_id]]*num_beams).cuda()), dim=-1).int()
        probs = selected_probs
        beams

        

        #beams = torch.cat((beams, torch.Tensor([[tokenizer.pad_token_id]]).cuda()), dim=-1).int()
    #seq = best_toks
# Out:
# torch.Size([3, 1]) tensor([0., 0., 0.], device='cuda:0')
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [16,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [1,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [17,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [0,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1284: indexSelectLargeIndex: block: [32,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 18
#      15 model.cuda()
#      16 #result = model.decoder.model(seq, encoder_hidden_states=image_embedding)
#      17 #print("input shape:", beams.shape)
# ---> 18 result = model(beams)
#      19 #print("result.shape", result.shape)
#      20 # (B, T, V)
#      21 best_toks = torch.topk(result[:, -1, :], num_beams, dim=-1)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/staffpad/code/research/omr/thirdparty/MEGABYTE-pytorch/MEGABYTE_pytorch/megabyte.py:355, in MEGABYTE.forward(self, ids, return_loss)
#     352 for ind, pos_emb, token_emb in zip_longest(range(len(prec_dims)), pos_embs, self.token_embs):
#     353     is_first = ind == 0
# --> 355     tokens = token_emb(ids)
#     357     if exists(pos_emb):
#     358         positions = pos_emb(torch.arange(tokens.shape[-2], device = device))
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/normalization.py:202, in LayerNorm.forward(self, input)
#     201 def forward(self, input: Tensor) -> Tensor:
# --> 202     return F.layer_norm(
#     203         input, self.normalized_shape, self.weight, self.bias, self.eps)
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/functional.py:2576, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2572 if has_torch_function_variadic(input, weight, bias):
#    2573     return handle_torch_function(
#    2574         layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2575     )
# -> 2576 return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
best_toks.values
# Out:
# tensor([[9.8109, 2.6513],
#         [7.4816, 4.8467]], device='cuda:0')

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 torch.save(model.cpu().state_dict(), "text_only_model.pt")
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/lightning/fabric/utilities/device_dtype_mixin.py:82, in _DeviceDtypeModuleMixin.cpu(self)
#      80 """See :meth:`torch.nn.Module.cpu`."""
#      81 _update_properties(self, device=torch.device("cpu"))
# ---> 82 return super().cpu()
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:965, in Module.cpu(self)
#     956 def cpu(self: T) -> T:
#     957     r"""Move all model parameters and buffers to the CPU.
#     958
#     959     .. note::
#    (...)
#     963         Module: self
#     964     """
# --> 965     return self._apply(lambda t: t.cpu())
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:805, in Module._apply(self, fn, recurse)
#     801 # Tensors stored in modules are graph leaves, and we don't want to
#     802 # track autograd history of `param_applied`, so we have to use
#     803 # `with torch.no_grad():`
#     804 with torch.no_grad():
# --> 805     param_applied = fn(param)
#     806 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     808 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/.virtualenvs/omr/lib/python3.10/site-packages/torch/nn/modules/module.py:965, in Module.cpu.<locals>.<lambda>(t)
#     956 def cpu(self: T) -> T:
#     957     r"""Move all model parameters and buffers to the CPU.
#     958
#     959     .. note::
#    (...)
#     963         Module: self
#     964     """
# --> 965     return self._apply(lambda t: t.cpu())
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
all_new_probs
# Out:
# tensor([104, 112, 104, 112], device='cuda:0')

# %%
selected_beams
# Out:
# tensor([[[ 84, 257],
#          [104, 112]]], device='cuda:0', dtype=torch.int32)

# %%
num_beams = 2
all_new_probs = (probs.repeat((num_beams, 1)).transpose(1, 0).reshape(1, -1) * n + best_toks.values.reshape(1,-1)) / (n+1)
print(all_new_probs)
selected = torch.topk(all_new_probs, num_beams)
selected_beam_indices = selected.indices.squeeze() // num_beams
selected_new_toks = selected.indices.squeeze() - selected_beam_indices

selected_beams = beams[selected_beam_indices]
#selected_beams[-1] = selected_new_toks
selected_tok_indices = selected_beam_indices * num_beams + selected_new_toks
selected_toks = best_toks.indices.reshape(-1)[selected_tok_indices]
selected_probs = all_new_probs.reshape(-1)[selected_tok_indices]
selected_toks, selected_probs
selected_beams[:, -1] = selected_toks.squeeze()
beams = torch.cat((selected_beams, torch.Tensor([[tokenizer.pad_token_id]]*num_beams).cuda()), dim=-1).int()
probs = selected_probs
beams
# Out:
# tensor([[8.2995, 5.2194, 5.9308, 4.0910]], device='cuda:0')
# tensor([[ 84, 104, 104, 104, 104, 104, 104, 257],
#         [ 84, 104, 104, 104, 104, 112, 112, 257]], device='cuda:0',
#        dtype=torch.int32)

# %%
selected_beams[:, -1] = selected_toks.squeeze()

# %%
selected_beams, selected_toks, selected_beams[:, -1]
# Out:
# (tensor([[ 84, 104],
#          [ 84, 112]], device='cuda:0', dtype=torch.int32),
#  tensor([104, 112], device='cuda:0'),
#  tensor([104, 112], device='cuda:0', dtype=torch.int32))

# %%
selected = torch.topk(best_toks.values.reshape(-1), 2, )
new_probs = selected.values
selected_beams =a selected.indices // num_beams
selected_new_toks = best_toks.indices.reshape(-1)[selected.indices]
selected_new_toks
# Out:
# tensor([84, 84], device='cuda:0')

# %%
import math

def beam_search(start, transition_fn, score_fn, beam_width, max_len):
    # `start`: the initial state
    # `transition_fn`: a function that takes a state and returns a list of (action, next_state) pairs
    # `score_fn`: a function that takes an action and returns a score
    # `beam_width`: the number of candidates to keep at each step
    # `max_len`: the maximum length of the output sequence
    
    # Initialize the beam with the start state
    beam = [(start, [], 0)]
    
    # Iterate until we reach the maximum length or run out of candidates
    for i in range(max_len):
        candidates = []
        
        # Generate new candidates by expanding each current candidate
        for state, seq, score in beam:
            for action, next_state in transition_fn(state):
                new_seq = seq + [action]
                new_score = score + score_fn(action)
                candidates.append((next_state, new_seq, new_score))
                
        # Select the top `beam_width` candidates based on their scores
        beam = sorted(candidates, key=lambda x: x[2], reverse=True)[:beam_width]
        
    # Return the sequence with the highest score
    return max(beam, key=lambda x: x[2])[1]

# %%
output_ids = torch.argmax(result, dim=-1)
output_ids
# Out:
# tensor([[ 84, 104, 105, 115,  32, 112, 105,  99, 116, 117, 114, 101,  32,  99,
#          111, 110, 116,  97, 105, 110, 115,  32,  97,  32,  97, 103,  97, 118,
#          101,  95,  97, 109, 101, 114, 105,  99,  97, 110,  97,  32, 112, 108,
#           97, 110, 116, 256,  97, 116,  97,  97,  97,  97,  97,  97,  97,  97,
#           97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,
#           97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,
#           97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,
#           97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,
#           97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,  97,
#           97,  97]], device='cuda:0')

# %%
toks
# Out:
# tensor([ 84, 104, 105, 115,  32, 112, 105,  99, 116, 117, 114, 101,  32,  99,
#         111, 110, 116,  97, 105, 110, 115,  32,  97,  32,  97, 103,  97, 118,
#         101,  95,  97, 109, 101, 114, 105,  99,  97, 110,  97,  32, 112, 108,
#          97, 110, 116, 256, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#         257, 257])

# %%
tokenizer.eos_token_id
# Out:
# 256

# %%
prompt = tokenizer(['This picture imag'])
#prompt = torch.Tensor([tokenizer.pad_token_id]*128).int().cuda().unsqueeze(0)

with torch.no_grad():
    result = model.decoder.model(prompt.cuda(), encoder_hidden_states=image_embedding)

tokenizer.decode(torch.argmax(result, dim=-1))
# Out:
# ['This picture imaga a agghagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaagaaag']

# %%
best_toks = 
best_toks
# Out:
# tensor([[ 84, 104, 105, 115,  32, 112, 105,  99,  84, 117, 114, 101,  32, 104,
#          105,  97,  32, 104,  97, 100,  32, 117,  97, 100,  32, 117,  97, 100,
#           32, 117,  97, 100,  32, 117,  97, 100,  32, 117,  97, 100,  32, 117,
#           97, 100,  32, 117,  97, 100,  32, 117,  97, 100,  32, 117,  97, 100,
#           32, 117,  97, 100,  32, 117,  97, 100,  32, 117,  97, 100,  32, 117,
#           97, 100,  32, 117,  97, 100,  32, 117,  97, 100,  32, 117,  97, 100,
#           32, 117,  97, 100,  32, 117,  97, 103,  32, 117,  97, 103,  32, 117,
#           97, 103,  32, 117,  97, 103,  32, 117,  97, 103,  32, 117,  97, 103,
#           32, 117,  97, 103,  32, 117,  97, 103,  32, 117,  97, 103,  32, 117,
#           97, 103]], device='cuda:0')

# %%
# Out:
# tensor([[ 84, 104, 105, 115,  32, 112, 105,  99, 116, 117, 114, 101,  32, 105,
#          109,  97, 103, 101, 115,  32,  97,  32,  97, 101,  99, 104, 109, 101,
#           97, 256, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257, 257,
#          257, 257]])

# %%
from queue import PriorityQueue
import operator

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class BeamSearchNode(object):
    def __init__(self, 
                 #hiddenstate, 
                 previousNode, wordId, logProb, length):
        '''
        :param hiddenstate:
        :param previousNode:
        :param wordId:
        :param logProb:
        :param length:
        '''
        #self.h = hiddenstate
        self.prevNode = previousNode
        self.wordid = wordId
        self.logp = logProb
        self.leng = length

    def eval(self, alpha=1.0):
        reward = 0
        # Add here a function for shaping a reward

        return self.logp / float(self.leng - 1 + 1e-6) + alpha * reward



    


def beam_decode(num_sentences, encoder_outputs=None):
    '''
    :param target_tensor: target indexes tensor of shape [B, T] where B is the batch size and T is the maximum length of the output sentence
    :param decoder_hidden: input tensor of shape [1, B, H] for start of the decoding
    :param encoder_outputs: if you are using attention mechanism you can pass encoder outputs, [T, B, H] where T is the maximum length of input sentence
    :return: decoded_batch
    '''

    beam_width = 10
    topk = 1  # how many sentence do you want to generate
    decoded_batch = []

    # decoding goes sentence by sentence
    for idx in range(num_sentences):
        #if isinstance(decoder_hiddens, tuple):  # LSTM case
        #    decoder_hidden = (decoder_hiddens[0][:,idx, :].unsqueeze(0),decoder_hiddens[1][:,idx, :].unsqueeze(0))
        #else:
        #    decoder_hidden = decoder_hiddens[:, idx, :].unsqueeze(0)
        #encoder_output = encoder_outputs[:,idx, :].unsqueeze(1)

        # Start with the start of the sentence token
        decoder_input = torch.Tensor([[decoder.config.pad_token_id]]).long().to(device)

        # Number of sentence to generate
        endnodes = []
        number_required = min((topk + 1), topk - len(endnodes))

        # starting node -  hidden vector, previous node, word id, logp, length
        node = BeamSearchNode(None, decoder_input, 0, 1)
        nodes = PriorityQueue()

        # start the queue
        nodes.put((-node.eval(), node))
        qsize = 1

        # start beam search
        while True:
            # give up when decoding takes too long
            if qsize > 20: break

            # fetch the best node
            score, n = nodes.get()
            decoder_input = n.wordid
            #decoder_hidden = n.h

            if n.wordid.item() == decoder.config.eos_token_id and n.prevNode != None:
                endnodes.append((score, n))
                # if we reached maximum # of sentences required
                if len(endnodes) >= number_required:
                    break
                else:
                    continue

            # decode for one step using decoder
            print(decoder_input)
            decoder_output = decoder.model(decoder_input, encoder_hidden_states=encoder_outputs)
            decoder_output = decoder_output[0]
            # PUT HERE REAL BEAM SEARCH OF TOP
            log_prob, indexes = torch.topk(decoder_output, beam_width)
            nextnodes = []

            for new_k in range(beam_width):
                decoded_t = indexes[0][new_k].view(1, -1)
                print(log_prob.shape)
                log_p = log_prob[0][new_k].item()

                node = BeamSearchNode(n, decoded_t, n.logp + log_p, n.leng + 1)
                score = -node.eval()
                nextnodes.append((score, node))

            # put them into queue
            for i in range(len(nextnodes)):
                score, nn = nextnodes[i]
                nodes.put((score, nn))
                # increase qsize
            qsize += len(nextnodes) - 1

        # choose nbest paths, back trace them
        if len(endnodes) == 0:
            endnodes = [nodes.get() for _ in range(topk)]

        utterances = []
        for score, n in sorted(endnodes, key=operator.itemgetter(0)):
            utterance = []
            utterance.append(n.wordid)
            # back trace
            while n.prevNode != None:
                n = n.prevNode
                utterance.append(n.wordid)

            utterance = utterance[::-1]
            utterances.append(utterance)

        decoded_batch.append(utterances)

    return decoded_batch

beam_decode(1)
# Out:
# tensor([[257]], device='cuda:0')
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# tensor([[84]], device='cuda:0')
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# tensor([[84]], device='cuda:0')
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# torch.Size([1, 10])
# [[[tensor([[257]], device='cuda:0'),
#    tensor([[84]], device='cuda:0'),
#    tensor([[84]], device='cuda:0'),
#    tensor([[84]], device='cuda:0')]]]

# %%
x =
